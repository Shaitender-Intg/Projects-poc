# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaitender/Projects-poc/blob/master/Keras_fashion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-tuner
# Out:
# ...
#      |████████████████████████████████| 92kB 3.7MB/s
# ...
#      |████████████████████████████████| 421.8MB 42kB/s
# ...
#      |████████████████████████████████| 3.8MB 60.6MB/s
# ...
#      |████████████████████████████████| 450kB 47.8MB/s
# ...
#      |████████████████████████████████| 81kB 13.7MB/s
# ...
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15354 sha256=86170329f4b763a67e7f4de66eefdb6d525f08f88b9cf4398307cc462bd97304
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# Successfully built terminaltables
# ERROR: tensorflow 2.1.0rc2 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.3.3 which is incompatible.
# ERROR: tensorboard 2.1.0 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.10.0 which is incompatible.
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
print(keras.datasets.fashion_mnist.load_data.__doc__)
# Out:
# Loads the Fashion-MNIST dataset.
#
#   Returns:
#       Tuple of Numpy arrays: `(x_train, y_train), (x_test, y_test)`.
#
#   License:
#       The copyright for Fashion-MNIST is held by Zalando SE.
#       Fashion-MNIST is licensed under the [MIT license](
#       https://github.com/zalandoresearch/fashion-mnist/blob/master/LICENSE).

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt


plt.figure()
plt.imshow(x_train[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
x_train = x_train / 255.0

x_test = x_test / 255.0

# %%
x_train[0].shape
x_test[0].shape
# Out:
# (28, 28)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_test[i])    
plt.show()
